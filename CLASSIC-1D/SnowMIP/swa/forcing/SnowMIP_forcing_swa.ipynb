# %% [markdown]
# # Check SnowMIP forcing files
#
# Both forcings are supposed to be the same. Menard et al. (2019) has the advantage to include the evaluation data also.
#
# - Krinner et al. (2018): https://gmd.copernicus.org/articles/11/5027/2018/ (data: https://www.geos.ed.ac.uk/~ressery/ESM-SnowMIP/netcdf.zip)
# - Menard et al. (2019) : https://essd.copernicus.org/articles/11/865/2019/ (data: https://doi.org/10.1594/PANGAEA.897575)

# %%
# Env: sc2_v0

import xarray as xr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import proplot as pplt # New plot library (https://proplot.readthedocs.io/en/latest/)
pplt.rc['savefig.dpi'] = 300 # 1200 is too big! #https://proplot.readthedocs.io/en/latest/basics.html#Creating-figures

# %%
path = '/home/lalandmi/Dropbox/data/ESM-SnowMIP_all' # menard

# %% [markdown]
# ## Swamp Angel, Colorado, USA

# %%
ds = xr.open_dataset(path+'/met_insitu_swa_2005_2015.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 87648)
# Coordinates:
#   * time     (time) datetime64[ns] 2005-10-01T01:00:00 ... 2015-10-01
# Data variables:
#     LWdown   (time) float32 ...
#     Psurf    (time) float32 ...
#     Qair     (time) float32 ...
#     Rainf    (time) float32 ...
#     Snowf    (time) float32 ...
#     SWdown   (time) float32 ...
#     Tair     (time) float32 ...
#     Wind     (time) float32 ...

# %% [markdown]
# ### SWDown

# %%
ds.SWdown
# Out:
# <xarray.DataArray 'SWdown' (time: 87648)>
# [87648 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2005-10-01T01:00:00 ... 2015-10-01
# Attributes:
#     ALMA_name:  SWdown
#     CMIP_name:  rsds
#     long_name:  Surface downward shortwave radiation
#     units:      W/m2

# %%
# Local time?
# ds.SWdown.sel(time='1998-01-01').plot()
ds.SWdown.sel(time='2008-01-01').plot()

# %%
# %matplotlib widget
ds.SWdown.plot(figsize=(8,4))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### LWDown

# %%
ds.LWdown
# Out:
# <xarray.DataArray 'LWdown' (time: 87648)>
# [87648 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2005-10-01T01:00:00 ... 2015-10-01
# Attributes:
#     ALMA_name:  LWdown
#     CMIP_name:  rlds
#     long_name:  Surface downward longwave radiation
#     units:      W/m2

# %%
# %matplotlib widget
ds.LWdown.plot(figsize=(8,4))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Rainf

# %%
ds.Rainf
# Out:
# <xarray.DataArray 'Rainf' (time: 87648)>
# [87648 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2005-10-01T01:00:00 ... 2015-10-01
# Attributes:
#     ALMA_name:  Rainf
#     CMIP_name:  prra
#     long_name:  Rainfall rate
#     units:      kg/m2/s

# %%
# %matplotlib widget
ds.Rainf.plot(figsize=(8,4))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Snowf

# %%
ds.Snowf
# Out:
# <xarray.DataArray 'Snowf' (time: 87648)>
# [87648 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2005-10-01T01:00:00 ... 2015-10-01
# Attributes:
#     ALMA_name:  Snowf
#     CMIP_name:  prsn
#     long_name:  Snowfall rate
#     units:      kg/m2/s

# %%
# %matplotlib widget
ds.Snowf.plot(figsize=(8,4))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Near-surface air temperature

# %%
ds.Tair
# Out:
# <xarray.DataArray 'Tair' (time: 87648)>
# [87648 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2005-10-01T01:00:00 ... 2015-10-01
# Attributes:
#     ALMA_name:  Tair
#     CMIP_name:  ta
#     long_name:  Near-surface air temperature
#     units:      K

# %%
# %matplotlib widget
ds.Tair.plot(figsize=(8,4))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Qair

# %%
ds.Qair
# Out:
# <xarray.DataArray 'Qair' (time: 87648)>
# [87648 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2005-10-01T01:00:00 ... 2015-10-01
# Attributes:
#     ALMA_name:  Qair
#     CMIP_name:  hus
#     long_name:  Near-surface specific humidity
#     units:      kg/kg

# %%
# %matplotlib widget
ds.Qair.plot(figsize=(8,4))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Wind

# %%
ds.Wind
# Out:
# <xarray.DataArray 'Wind' (time: 87648)>
# [87648 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2005-10-01T01:00:00 ... 2015-10-01
# Attributes:
#     ALMA_name:  Wind
#     CMIP_name:  ws
#     long_name:  Near-surface wind speed
#     units:      m/s

# %%
# %matplotlib widget
ds.Wind.plot(figsize=(8,4))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Psurf

# %%
ds.Psurf
# Out:
# <xarray.DataArray 'Psurf' (time: 87648)>
# [87648 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 2005-10-01T01:00:00 ... 2015-10-01
# Attributes:
#     ALMA_name:  Psurf
#     CMIP_name:  ps
#     long_name:  Surface downward longwave radiation
#     units:      Pa

# %%
# %matplotlib widget
ds.Psurf.plot(figsize=(8,4))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
